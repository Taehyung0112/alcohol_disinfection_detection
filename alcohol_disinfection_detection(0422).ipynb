# %%
import os
import cv2
from ultralytics import YOLO
import mediapipe as mp
import time

# === 設定路徑 ===
YOLO_DISPENSER_MODEL = "/home/yangzhelun/Desktop/alcohol_disinfection_detection(0425)/dispensor weight/best(yolov11).engine"
YOLO_PEOPLE_MODEL = "/home/yangzhelun/Desktop/alcohol_disinfection_detection(0425)/dispensor weight/yolo11n.engine"
VIDEO_INPUT = "/home/yangzhelun/Desktop/alcohol_disinfection_detection(0425)/Input Video/test2.mp4"
VIDEO_OUTPUT = "/home/yangzhelun/Desktop/alcohol_disinfection_detection(0425)/Output Video/processed_video.mp4"

# === Mediapipe 初始化 ===
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=2, min_detection_confidence=0.3, min_tracking_confidence=0.3)
mp_draw = mp.solutions.drawing_utils

# === 載入 YOLO TensorRT 模型 ===
model_people = YOLO(YOLO_PEOPLE_MODEL)
model_dispenser = YOLO(YOLO_DISPENSER_MODEL)

# === 全域參數 ===
dispenser_roi = None
sanitized_count = 0
sanitized_ids = set()
track_state = {}
DELAY_TIME = 3
DISPENSER_DETECT_FRAMES = 100
dispenser_detected = False

# === 初始化影片 ===
def initialize_video(input_path, output_path):
    cap = cv2.VideoCapture(input_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))
    return cap, out, fps, frame_width, frame_height

# === 偵測酒精機位置 + 畫框 ===
def detect_dispenser(frame):
    results = model_dispenser(frame)
    for r in results:
        for box in r.boxes:
            cls_id = int(box.cls.item())
            label = r.names[cls_id]
            confidence = box.conf[0]
            if label.lower() == "dispenser" and confidence > 0.3:
                coords = list(map(int, box.xyxy[0]))
                cv2.rectangle(frame, (coords[0], coords[1]), (coords[2], coords[3]), (255, 0, 255), 2)
                cv2.putText(frame, "Dispenser", (coords[0], coords[1] - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 255), 2)
                print(f"\n✅ Dispenser detected at: {coords}")
                return coords
    return None

# === 主人物追蹤與手部對應邏輯 ===
def process_tracking_optimized(frame, results_people, dispenser_roi, w, h, current_time, frame_count):
    global sanitized_count

    # === 全圖執行 Mediapipe ===
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(rgb)
    hands_xy = []

    if results.multi_hand_landmarks:
        print(f"🖐️ Detected {len(results.multi_hand_landmarks)} hand(s)")
        for i, hand_landmarks in enumerate(results.multi_hand_landmarks):
            wrist = hand_landmarks.landmark[mp_hands.HandLandmark.WRIST]
            x = int(wrist.x * w)
            y = int(wrist.y * h)
            print(f"   ↳ Hand {i} wrist at ({x}, {y})")
            hands_xy.append((x, y))
            mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            cv2.circle(frame, (x, y), 6, (0, 0, 255), -1)

    # === 畫出液區區塊 ===
    height = dispenser_roi[3] - dispenser_roi[1]
    lower_y1 = dispenser_roi[1] + int(height * 0.8)
    lower_y2 = dispenser_roi[3] + int(height * 0.3)
    overlay = frame.copy()
    cv2.rectangle(overlay, (dispenser_roi[0], lower_y1), (dispenser_roi[2], lower_y2), (0, 255, 255), -1)
    frame[:] = cv2.addWeighted(overlay, 0.3, frame, 0.7, 0)

    # === YOLO 人物框收集 ===
    people_boxes = {}
    for r in results_people:
        if r.boxes.id is None:
            continue
        for box, track_id_tensor in zip(r.boxes, r.boxes.id):
            track_id = int(track_id_tensor.item())
            cls_id = int(box.cls.item())
            label = r.names[cls_id]
            if label != "person":
                continue
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            people_boxes[track_id] = (x1, y1, x2, y2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"ID: {track_id}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # === 檢查是否有手進入出液區
    triggered_hand = None
    for hx, hy in hands_xy:
        if dispenser_roi[0] <= hx <= dispenser_roi[2] and lower_y1 <= hy <= lower_y2:
            triggered_hand = (hx, hy)
            print(f"✅ Hand entered disinfection zone at ({hx}, {hy})")
            break

    # === 找距離最近的人並觸發消毒邏輯
    if triggered_hand and people_boxes:
        min_dist = float('inf')
        target_id = None
        for track_id, (x1, y1, x2, y2) in people_boxes.items():
            cx = (x1 + x2) // 2
            cy = (y1 + y2) // 2
            dist = ((cx - triggered_hand[0]) ** 2 + (cy - triggered_hand[1]) ** 2) ** 0.5
            if dist < min_dist:
                min_dist = dist
                target_id = track_id
        print(f"🎯 Closest person to hand: ID {target_id} (distance={min_dist:.2f})")

        if target_id is not None:
            track_state.setdefault(target_id, {'last_detected': 0, 'show_text': False})
            if (current_time - track_state[target_id]['last_detected']) > DELAY_TIME:
                if target_id not in sanitized_ids:
                    sanitized_ids.add(target_id)
                    sanitized_count += 1
                    print(f"✅ Person ID {target_id} triggered disinfection")
                track_state[target_id] = {'last_detected': current_time, 'show_text': True}

            if track_state[target_id]['show_text']:
                cv2.putText(frame, f"detected {target_id} Sanitization Success!", (w // 4, h // 2),
                            cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)

# === 主程式 ===
cap, out, fps, frame_width, frame_height = initialize_video(VIDEO_INPUT, VIDEO_OUTPUT)
frame_count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("處理完成")
        break

    current_time = time.time()
    h, w, _ = frame.shape

    if not dispenser_detected and frame_count < DISPENSER_DETECT_FRAMES:
        roi_candidate = detect_dispenser(frame)
        if roi_candidate:
            dispenser_roi = roi_candidate
            dispenser_detected = True
            print("Dispenser position fixed:", dispenser_roi)

    if dispenser_roi:
        results_people = model_people.track(frame, persist=True, tracker="botsort.yaml")
        process_tracking_optimized(frame, results_people, dispenser_roi, w, h, current_time, frame_count)

    cv2.putText(frame, f"Sanitized Count: {sanitized_count}", (10, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    out.write(frame)
    display_frame = cv2.resize(frame, (1280, 720))  # Or any size that fits your screen
    cv2.imshow("Jetson Nano Sanitization Detection", display_frame)


    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    frame_count += 1

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading /home/yangzhelun/Desktop/alcohol_disinfection_detection(0425)/dispensor weight/best(yolov11).engine for TensorRT inference...
# [04/25/2025-16:05:38] [TRT] [I] The logger passed into createInferRuntime differs from one already provided for an existing builder, runtime, or refitter. Uses of the global logger, returned by nvinfer1::getLogger(), will return the existing value.
#
# [04/25/2025-16:05:39] [TRT] [I] Loaded engine size: 6 MiB
# [04/25/2025-16:05:40] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +101, now: CPU 1876, GPU 5614 (MiB)
# [04/25/2025-16:05:40] [TRT] [I] [MemUsageChange] Init cuDNN: CPU +1, GPU +30, now: CPU 1877, GPU 5644 (MiB)
# [04/25/2025-16:05:40] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +5, now: CPU 1, GPU 44 (MiB)
# [04/25/2025-16:05:40] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 1870, GPU 5565 (MiB)
# [04/25/2025-16:05:40] [TRT] [I] [MemUsageChange] Init cuDNN: CPU +0, GPU +0, now: CPU 1870, GPU 5565 (MiB)
# [04/25/2025-16:05:40] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +17, now: CPU 1, GPU 61 (MiB)
#
# 0: 640x640 (no detections), 34.3ms
# Speed: 48.5ms preprocess, 34.3ms inference, 73.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 34.3ms
# Speed: 33.7ms preprocess, 34.3ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 24.1ms
# Speed: 8.7ms preprocess, 24.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 28.2ms
# Speed: 9.9ms preprocess, 28.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.8ms
# Speed: 11.7ms preprocess, 18.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.9ms
# Speed: 12.1ms preprocess, 20.9ms inference, 10.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.2ms
# Speed: 9.6ms preprocess, 18.2ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.9ms
# Speed: 8.9ms preprocess, 20.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.2ms
# Speed: 6.9ms preprocess, 18.2ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.3ms
# Speed: 7.8ms preprocess, 18.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.3ms
# Speed: 6.9ms preprocess, 18.3ms inference, 16.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 19.0ms
# Speed: 7.4ms preprocess, 19.0ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.9ms
# Speed: 10.4ms preprocess, 20.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 23.0ms
# Speed: 27.2ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 33.9ms
# Speed: 31.3ms preprocess, 33.9ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 28.8ms
# Speed: 18.7ms preprocess, 28.8ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 31.7ms
# Speed: 14.0ms preprocess, 31.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 17.5ms
# Speed: 17.4ms preprocess, 17.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 53.3ms
# Speed: 8.8ms preprocess, 53.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.8ms
# Speed: 28.3ms preprocess, 20.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 24.1ms
# Speed: 17.8ms preprocess, 24.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 9.1ms preprocess, 15.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 7.7ms preprocess, 15.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.0ms
# Speed: 6.6ms preprocess, 15.0ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.3ms
# Speed: 6.4ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 21.7ms preprocess, 15.1ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.2ms
# Speed: 6.4ms preprocess, 15.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.0ms
# Speed: 10.4ms preprocess, 15.0ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.0ms
# Speed: 7.0ms preprocess, 15.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 6.7ms preprocess, 15.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 7.7ms preprocess, 15.1ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.0ms
# Speed: 13.9ms preprocess, 15.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.3ms
# Speed: 7.5ms preprocess, 18.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.7ms
# Speed: 6.6ms preprocess, 20.7ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 19.7ms
# Speed: 7.0ms preprocess, 19.7ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 21.1ms
# Speed: 6.6ms preprocess, 21.1ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.3ms
# Speed: 7.9ms preprocess, 18.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 19.9ms
# Speed: 6.9ms preprocess, 19.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 19.5ms
# Speed: 7.7ms preprocess, 19.5ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.3ms
# Speed: 6.9ms preprocess, 18.3ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.4ms
# Speed: 7.4ms preprocess, 18.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.8ms
# Speed: 8.5ms preprocess, 18.8ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 23.1ms
# Speed: 16.0ms preprocess, 23.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.3ms
# Speed: 16.5ms preprocess, 20.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.2ms
# Speed: 7.5ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.1ms
# Speed: 7.2ms preprocess, 18.1ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.5ms
# Speed: 6.4ms preprocess, 18.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.5ms
# Speed: 8.8ms preprocess, 20.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 24.5ms
# Speed: 8.0ms preprocess, 24.5ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 21.6ms
# Speed: 20.5ms preprocess, 21.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.5ms
# Speed: 7.6ms preprocess, 18.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.4ms
# Speed: 8.5ms preprocess, 15.4ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 16.5ms
# Speed: 9.1ms preprocess, 16.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.5ms
# Speed: 8.9ms preprocess, 15.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 8.0ms preprocess, 15.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 8.5ms preprocess, 15.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 16.7ms
# Speed: 9.9ms preprocess, 16.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.2ms
# Speed: 7.5ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 14.9ms
# Speed: 7.1ms preprocess, 14.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.9ms
# Speed: 33.5ms preprocess, 20.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 7.2ms preprocess, 15.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.3ms
# Speed: 9.7ms preprocess, 15.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.9ms
# Speed: 7.8ms preprocess, 20.9ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 16.3ms
# Speed: 8.7ms preprocess, 16.3ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 471.3ms
# Speed: 107.1ms preprocess, 471.3ms inference, 67.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 18.2ms
# Speed: 19.2ms preprocess, 18.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 dispenser, 21.4ms
# Speed: 11.8ms preprocess, 21.4ms inference, 181.7ms postprocess per image at shape (1, 3, 640, 640)
#
# ✅ Dispenser detected at: [0, 391, 1084, 1987]
# Dispenser position fixed: [0, 391, 1084, 1987]
# Loading /home/yangzhelun/Desktop/alcohol_disinfection_detection(0425)/dispensor weight/yolo11n.engine for TensorRT inference...
# [04/25/2025-16:06:07] [TRT] [I] The logger passed into createInferRuntime differs from one already provided for an existing builder, runtime, or refitter. Uses of the global logger, returned by nvinfer1::getLogger(), will return the existing value.
#
# [04/25/2025-16:06:07] [TRT] [I] Loaded engine size: 6 MiB
# [04/25/2025-16:06:08] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +75, now: CPU 2028, GPU 5819 (MiB)
# [04/25/2025-16:06:08] [TRT] [I] [MemUsageChange] Init cuDNN: CPU +1, GPU +49, now: CPU 2029, GPU 5868 (MiB)
# [04/25/2025-16:06:08] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +6, now: CPU 1, GPU 67 (MiB)
# [04/25/2025-16:06:08] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +32, now: CPU 2022, GPU 5900 (MiB)
# [04/25/2025-16:06:08] [TRT] [I] [MemUsageChange] Init cuDNN: CPU +0, GPU +1, now: CPU 2022, GPU 5900 (MiB)
# [04/25/2025-16:06:08] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +1, GPU +11, now: CPU 2, GPU 78 (MiB)
#
# 0: 640x640 3 persons, 1 parking meter, 1 cell phone, 15.5ms
# Speed: 7.0ms preprocess, 15.5ms inference, 134.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1656, 711)
#
# 0: 640x640 3 persons, 1 parking meter, 1 cell phone, 34.8ms
# Speed: 25.8ms preprocess, 34.8ms inference, 14.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1669, 731)
#
# 0: 640x640 3 persons, 1 parking meter, 24.2ms
# Speed: 7.3ms preprocess, 24.2ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1715, 759)
#
# 0: 640x640 3 persons, 1 parking meter, 32.3ms
# Speed: 9.4ms preprocess, 32.3ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1773, 940)
#
# 0: 640x640 2 persons, 1 parking meter, 21.8ms
# Speed: 8.7ms preprocess, 21.8ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1844, 968)
#
# 0: 640x640 2 persons, 1 parking meter, 19.8ms
# Speed: 7.5ms preprocess, 19.8ms inference, 12.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2000, 999)
#
# 0: 640x640 2 persons, 1 parking meter, 21.4ms
# Speed: 8.6ms preprocess, 21.4ms inference, 23.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2117, 963)
#
# 0: 640x640 3 persons, 1 parking meter, 18.6ms
# Speed: 8.2ms preprocess, 18.6ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1802, 920)
#    ↳ Hand 1 wrist at (2203, 963)
#
# 0: 640x640 2 persons, 1 parking meter, 18.7ms
# Speed: 8.5ms preprocess, 18.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2172, 1005)
#
# 0: 640x640 3 persons, 1 parking meter, 18.7ms
# Speed: 8.5ms preprocess, 18.7ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2105, 1114)
#
# 0: 640x640 3 persons, 1 parking meter, 20.6ms
# Speed: 7.1ms preprocess, 20.6ms inference, 9.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2004, 1167)
#
# 0: 640x640 3 persons, 1 parking meter, 22.1ms
# Speed: 11.0ms preprocess, 22.1ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2020, 1265)
#
# 0: 640x640 3 persons, 1 parking meter, 20.8ms
# Speed: 9.1ms preprocess, 20.8ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2065, 1256)
#
# 0: 640x640 3 persons, 1 parking meter, 19.2ms
# Speed: 7.3ms preprocess, 19.2ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1631, 1127)
#    ↳ Hand 1 wrist at (2092, 1173)
#
# 0: 640x640 3 persons, 1 parking meter, 19.7ms
# Speed: 6.9ms preprocess, 19.7ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1824, 1161)
#    ↳ Hand 1 wrist at (2135, 1107)
#
# 0: 640x640 4 persons, 1 parking meter, 19.1ms
# Speed: 9.9ms preprocess, 19.1ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2065, 1142)
#
# 0: 640x640 3 persons, 1 parking meter, 21.4ms
# Speed: 16.1ms preprocess, 21.4ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1979, 1265)
#
# 0: 640x640 3 persons, 1 parking meter, 20.3ms
# Speed: 7.9ms preprocess, 20.3ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1631, 1249)
#    ↳ Hand 1 wrist at (1897, 1276)
#
# 0: 640x640 2 persons, 1 parking meter, 19.1ms
# Speed: 9.5ms preprocess, 19.1ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1915, 1375)
#
# 0: 640x640 3 persons, 1 parking meter, 27.4ms
# Speed: 13.2ms preprocess, 27.4ms inference, 13.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1967, 1355)
#
# 0: 640x640 3 persons, 18.6ms
# Speed: 8.4ms preprocess, 18.6ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1801, 1093)
#    ↳ Hand 1 wrist at (1951, 1326)
#
# 0: 640x640 3 persons, 21.4ms
# Speed: 6.8ms preprocess, 21.4ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1939, 1282)
#
# 0: 640x640 3 persons, 1 parking meter, 15.3ms
# Speed: 8.5ms preprocess, 15.3ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1878, 1291)
#
# 0: 640x640 2 persons, 1 parking meter, 15.6ms
# Speed: 27.2ms preprocess, 15.6ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1900, 1236)
#
# 0: 640x640 2 persons, 1 parking meter, 15.3ms
# Speed: 7.3ms preprocess, 15.3ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1978, 1187)
#
# 0: 640x640 2 persons, 1 parking meter, 15.5ms
# Speed: 8.8ms preprocess, 15.5ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2028, 1243)
#
# 0: 640x640 3 persons, 1 parking meter, 16.0ms
# Speed: 18.6ms preprocess, 16.0ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2025, 1390)
#
# 0: 640x640 2 persons, 1 parking meter, 16.1ms
# Speed: 7.6ms preprocess, 16.1ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1959, 1524)
#
# 0: 640x640 3 persons, 1 parking meter, 24.4ms
# Speed: 10.6ms preprocess, 24.4ms inference, 10.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1445, 1341)
#    ↳ Hand 1 wrist at (1880, 1649)
#
# 0: 640x640 4 persons, 1 parking meter, 15.6ms
# Speed: 6.7ms preprocess, 15.6ms inference, 16.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1450, 1508)
#    ↳ Hand 1 wrist at (1914, 1711)
#
# 0: 640x640 4 persons, 1 parking meter, 18.6ms
# Speed: 7.4ms preprocess, 18.6ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1369, 1591)
#    ↳ Hand 1 wrist at (1963, 1743)
#
# 0: 640x640 4 persons, 1 parking meter, 19.1ms
# Speed: 7.4ms preprocess, 19.1ms inference, 9.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1338, 1657)
#    ↳ Hand 1 wrist at (1951, 1915)
#
# 0: 640x640 4 persons, 1 parking meter, 18.5ms
# Speed: 8.4ms preprocess, 18.5ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1434, 1469)
#    ↳ Hand 1 wrist at (2064, 1838)
#
# 0: 640x640 4 persons, 1 parking meter, 23.1ms
# Speed: 13.7ms preprocess, 23.1ms inference, 14.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2096, 1934)
#
# 0: 640x640 4 persons, 1 parking meter, 22.8ms
# Speed: 13.0ms preprocess, 22.8ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2050, 1921)
#
# 0: 640x640 3 persons, 1 parking meter, 22.4ms
# Speed: 23.6ms preprocess, 22.4ms inference, 15.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1501, 1758)
#    ↳ Hand 1 wrist at (1913, 1994)
#
# 0: 640x640 2 persons, 1 parking meter, 19.0ms
# Speed: 7.3ms preprocess, 19.0ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1641, 1819)
#    ↳ Hand 1 wrist at (1811, 2008)
#
# 0: 640x640 2 persons, 1 parking meter, 19.1ms
# Speed: 17.9ms preprocess, 19.1ms inference, 13.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1709, 2074)
#
# 0: 640x640 2 persons, 1 parking meter, 29.9ms
# Speed: 6.6ms preprocess, 29.9ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1693, 2140)
#
# 0: 640x640 3 persons, 1 parking meter, 19.1ms
# Speed: 10.4ms preprocess, 19.1ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1674, 2146)
#
# 0: 640x640 3 persons, 1 parking meter, 18.6ms
# Speed: 8.2ms preprocess, 18.6ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1601, 2148)
#
# 0: 640x640 2 persons, 1 parking meter, 22.0ms
# Speed: 10.5ms preprocess, 22.0ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1547, 2099)
#
# 0: 640x640 1 person, 1 parking meter, 19.2ms
# Speed: 21.4ms preprocess, 19.2ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1477, 2126)
#
# 0: 640x640 1 person, 1 parking meter, 19.0ms
# Speed: 8.2ms preprocess, 19.0ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1838, 1563)
#    ↳ Hand 1 wrist at (1415, 2170)
#
# 0: 640x640 1 person, 1 parking meter, 19.3ms
# Speed: 7.8ms preprocess, 19.3ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1939, 1498)
#    ↳ Hand 1 wrist at (1361, 2189)
#
# 0: 640x640 1 person, 1 parking meter, 19.1ms
# Speed: 9.6ms preprocess, 19.1ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1987, 1456)
#    ↳ Hand 1 wrist at (1354, 2223)
#
# 0: 640x640 1 person, 1 parking meter, 18.7ms
# Speed: 7.8ms preprocess, 18.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2004, 1465)
#    ↳ Hand 1 wrist at (1373, 2210)
#
# 0: 640x640 1 person, 1 parking meter, 18.7ms
# Speed: 7.1ms preprocess, 18.7ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2027, 1473)
#    ↳ Hand 1 wrist at (1370, 2196)
#
# 0: 640x640 1 person, 1 parking meter, 20.5ms
# Speed: 17.3ms preprocess, 20.5ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2035, 1477)
#    ↳ Hand 1 wrist at (1370, 2207)
#
# 0: 640x640 1 person, 1 parking meter, 18.9ms
# Speed: 7.4ms preprocess, 18.9ms inference, 14.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2049, 1489)
#    ↳ Hand 1 wrist at (1344, 2187)
#
# 0: 640x640 1 person, 1 parking meter, 18.9ms
# Speed: 7.5ms preprocess, 18.9ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2056, 1481)
#    ↳ Hand 1 wrist at (1293, 2172)
#
# 0: 640x640 1 person, 1 truck, 1 parking meter, 18.6ms
# Speed: 8.0ms preprocess, 18.6ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2065, 1476)
#    ↳ Hand 1 wrist at (1235, 2141)
#
# 0: 640x640 1 person, 1 truck, 1 parking meter, 20.4ms
# Speed: 12.3ms preprocess, 20.4ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2069, 1493)
#    ↳ Hand 1 wrist at (1201, 2096)
#
# 0: 640x640 3 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 6.9ms preprocess, 18.6ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2073, 1493)
#    ↳ Hand 1 wrist at (1199, 2086)
#
# 0: 640x640 3 persons, 1 truck, 1 parking meter, 18.9ms
# Speed: 8.2ms preprocess, 18.9ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2078, 1496)
#    ↳ Hand 1 wrist at (1191, 2071)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 19.2ms
# Speed: 6.7ms preprocess, 19.2ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2079, 1499)
#    ↳ Hand 1 wrist at (1164, 2060)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 18.7ms
# Speed: 7.8ms preprocess, 18.7ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2078, 1497)
#    ↳ Hand 1 wrist at (1154, 2047)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 8.2ms preprocess, 18.6ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2079, 1497)
#    ↳ Hand 1 wrist at (1135, 2019)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 6.6ms preprocess, 18.6ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2082, 1500)
#    ↳ Hand 1 wrist at (1112, 2009)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 21.7ms
# Speed: 7.3ms preprocess, 21.7ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2085, 1499)
#    ↳ Hand 1 wrist at (1098, 2006)
#
# 0: 640x640 3 persons, 1 truck, 1 parking meter, 19.1ms
# Speed: 7.0ms preprocess, 19.1ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2080, 1489)
#    ↳ Hand 1 wrist at (1109, 1998)
#
# 0: 640x640 3 persons, 1 truck, 1 parking meter, 19.0ms
# Speed: 10.2ms preprocess, 19.0ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2074, 1489)
#    ↳ Hand 1 wrist at (1136, 2013)
#
# 0: 640x640 3 persons, 1 truck, 1 parking meter, 19.2ms
# Speed: 6.8ms preprocess, 19.2ms inference, 22.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2070, 1495)
#    ↳ Hand 1 wrist at (1083, 1990)
# ✅ Hand entered disinfection zone at (1083, 1990)
# 🎯 Closest person to hand: ID 3 (distance=282.72)
# ✅ Person ID 3 triggered disinfection
#
# 0: 640x640 3 persons, 1 truck, 1 parking meter, 19.0ms
# Speed: 18.6ms preprocess, 19.0ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2070, 1499)
#    ↳ Hand 1 wrist at (1104, 2019)
#
# 0: 640x640 3 persons, 1 truck, 1 parking meter, 23.2ms
# Speed: 16.5ms preprocess, 23.2ms inference, 20.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2071, 1504)
#    ↳ Hand 1 wrist at (1055, 1982)
# ✅ Hand entered disinfection zone at (1055, 1982)
# 🎯 Closest person to hand: ID 3 (distance=308.80)
#
# 0: 640x640 3 persons, 1 truck, 1 parking meter, 18.8ms
# Speed: 11.1ms preprocess, 18.8ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2072, 1512)
#    ↳ Hand 1 wrist at (1046, 2010)
# ✅ Hand entered disinfection zone at (1046, 2010)
# 🎯 Closest person to hand: ID 3 (distance=337.56)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 18.7ms
# Speed: 8.2ms preprocess, 18.7ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2066, 1511)
#    ↳ Hand 1 wrist at (1033, 2008)
# ✅ Hand entered disinfection zone at (1033, 2008)
# 🎯 Closest person to hand: ID 3 (distance=355.04)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 18.8ms
# Speed: 18.3ms preprocess, 18.8ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2070, 1508)
#    ↳ Hand 1 wrist at (1007, 2003)
# ✅ Hand entered disinfection zone at (1007, 2003)
# 🎯 Closest person to hand: ID 3 (distance=363.51)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 18.8ms
# Speed: 7.9ms preprocess, 18.8ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2067, 1518)
#    ↳ Hand 1 wrist at (1026, 2031)
# ✅ Hand entered disinfection zone at (1026, 2031)
# 🎯 Closest person to hand: ID 3 (distance=363.41)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 19.1ms
# Speed: 22.6ms preprocess, 19.1ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2071, 1518)
#    ↳ Hand 1 wrist at (1013, 2048)
# ✅ Hand entered disinfection zone at (1013, 2048)
# 🎯 Closest person to hand: ID 3 (distance=199.09)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 18.7ms
# Speed: 7.6ms preprocess, 18.7ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2065, 1514)
#    ↳ Hand 1 wrist at (1019, 2034)
# ✅ Hand entered disinfection zone at (1019, 2034)
# 🎯 Closest person to hand: ID 3 (distance=208.66)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 21.4ms
# Speed: 22.1ms preprocess, 21.4ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2074, 1529)
#    ↳ Hand 1 wrist at (1001, 2050)
# ✅ Hand entered disinfection zone at (1001, 2050)
# 🎯 Closest person to hand: ID 3 (distance=254.80)
#
# 0: 640x640 4 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 24.1ms preprocess, 18.6ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2071, 1527)
#    ↳ Hand 1 wrist at (1004, 2039)
# ✅ Hand entered disinfection zone at (1004, 2039)
# 🎯 Closest person to hand: ID 3 (distance=272.39)
#
# 0: 640x640 4 persons, 1 parking meter, 20.1ms
# Speed: 8.1ms preprocess, 20.1ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2074, 1534)
#    ↳ Hand 1 wrist at (998, 2035)
# ✅ Hand entered disinfection zone at (998, 2035)
# 🎯 Closest person to hand: ID 3 (distance=201.72)
#
# 0: 640x640 3 persons, 1 parking meter, 18.9ms
# Speed: 7.6ms preprocess, 18.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2069, 1526)
#    ↳ Hand 1 wrist at (1008, 2052)
# ✅ Hand entered disinfection zone at (1008, 2052)
# 🎯 Closest person to hand: ID 3 (distance=194.92)
#
# 0: 640x640 3 persons, 1 parking meter, 18.6ms
# Speed: 16.1ms preprocess, 18.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2070, 1532)
#    ↳ Hand 1 wrist at (1029, 2052)
# ✅ Hand entered disinfection zone at (1029, 2052)
# 🎯 Closest person to hand: ID 3 (distance=185.81)
#
# 0: 640x640 3 persons, 1 parking meter, 19.6ms
# Speed: 10.3ms preprocess, 19.6ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2067, 1510)
#    ↳ Hand 1 wrist at (1040, 2057)
# ✅ Hand entered disinfection zone at (1040, 2057)
# 🎯 Closest person to hand: ID 3 (distance=274.05)
#
# 0: 640x640 4 persons, 1 parking meter, 19.4ms
# Speed: 8.3ms preprocess, 19.4ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2076, 1510)
#    ↳ Hand 1 wrist at (1039, 2065)
# ✅ Hand entered disinfection zone at (1039, 2065)
# 🎯 Closest person to hand: ID 3 (distance=312.80)
#
# 0: 640x640 5 persons, 1 parking meter, 19.4ms
# Speed: 7.4ms preprocess, 19.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2080, 1516)
#    ↳ Hand 1 wrist at (1057, 2071)
# ✅ Hand entered disinfection zone at (1057, 2071)
# 🎯 Closest person to hand: ID 3 (distance=299.11)
#
# 0: 640x640 4 persons, 1 parking meter, 18.7ms
# Speed: 25.8ms preprocess, 18.7ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2092, 1526)
#    ↳ Hand 1 wrist at (1055, 2054)
# ✅ Hand entered disinfection zone at (1055, 2054)
# 🎯 Closest person to hand: ID 3 (distance=282.07)
#
# 0: 640x640 4 persons, 1 parking meter, 40.5ms
# Speed: 30.0ms preprocess, 40.5ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2104, 1538)
#    ↳ Hand 1 wrist at (1086, 2069)
#
# 0: 640x640 4 persons, 1 parking meter, 18.8ms
# Speed: 8.5ms preprocess, 18.8ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2089, 1525)
#    ↳ Hand 1 wrist at (1111, 2064)
#
# 0: 640x640 5 persons, 1 parking meter, 18.8ms
# Speed: 28.3ms preprocess, 18.8ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2090, 1531)
#    ↳ Hand 1 wrist at (1147, 2082)
#
# 0: 640x640 3 persons, 1 parking meter, 18.5ms
# Speed: 6.7ms preprocess, 18.5ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2095, 1550)
#    ↳ Hand 1 wrist at (1165, 2076)
#
# 0: 640x640 5 persons, 1 parking meter, 18.5ms
# Speed: 8.2ms preprocess, 18.5ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2097, 1540)
#    ↳ Hand 1 wrist at (1192, 2083)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 18.7ms
# Speed: 19.4ms preprocess, 18.7ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2091, 1533)
#    ↳ Hand 1 wrist at (1213, 2078)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 19.3ms
# Speed: 8.1ms preprocess, 19.3ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2086, 1533)
#    ↳ Hand 1 wrist at (1272, 2092)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 21.1ms
# Speed: 8.3ms preprocess, 21.1ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2076, 1525)
#    ↳ Hand 1 wrist at (1322, 2149)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 18.7ms
# Speed: 16.8ms preprocess, 18.7ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2060, 1501)
#    ↳ Hand 1 wrist at (1373, 2180)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 18.7ms
# Speed: 9.4ms preprocess, 18.7ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2042, 1519)
#    ↳ Hand 1 wrist at (1459, 2202)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 18.5ms
# Speed: 8.0ms preprocess, 18.5ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (2015, 1516)
#    ↳ Hand 1 wrist at (1558, 2222)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 8.7ms preprocess, 18.6ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1988, 1519)
#    ↳ Hand 1 wrist at (1663, 2210)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 18.9ms
# Speed: 7.6ms preprocess, 18.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1963, 1528)
#    ↳ Hand 1 wrist at (1760, 2225)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 8.2ms preprocess, 18.6ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1940, 1541)
#    ↳ Hand 1 wrist at (1839, 2213)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 19.2ms
# Speed: 12.2ms preprocess, 19.2ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1906, 1551)
#    ↳ Hand 1 wrist at (1890, 2173)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 19.2ms
# Speed: 8.9ms preprocess, 19.2ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1886, 1593)
#    ↳ Hand 1 wrist at (1935, 2128)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 19.4ms
# Speed: 9.5ms preprocess, 19.4ms inference, 10.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1880, 1696)
#    ↳ Hand 1 wrist at (2014, 2109)
#
# 0: 640x640 8 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 7.9ms preprocess, 18.6ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1876, 1664)
#    ↳ Hand 1 wrist at (2046, 2049)
#
# 0: 640x640 8 persons, 1 truck, 1 parking meter, 20.5ms
# Speed: 9.4ms preprocess, 20.5ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2055, 1992)
#
# 0: 640x640 8 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 8.0ms preprocess, 18.6ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2032, 1960)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 31.9ms
# Speed: 24.6ms preprocess, 31.9ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2059, 1927)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 1 backpack, 34.6ms
# Speed: 10.8ms preprocess, 34.6ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2081, 1878)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 1 backpack, 18.7ms
# Speed: 6.6ms preprocess, 18.7ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2212, 1774)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 1 backpack, 19.8ms
# Speed: 7.8ms preprocess, 19.8ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2245, 1707)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 1 backpack, 18.7ms
# Speed: 6.9ms preprocess, 18.7ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1830, 1662)
#    ↳ Hand 1 wrist at (2167, 1745)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 18.8ms
# Speed: 8.1ms preprocess, 18.8ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2070, 1896)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 18.7ms
# Speed: 7.0ms preprocess, 18.7ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2004, 1958)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 18.6ms
# Speed: 8.9ms preprocess, 18.6ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1949, 1871)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 27.2ms
# Speed: 8.6ms preprocess, 27.2ms inference, 17.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1806, 1972)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 19.3ms
# Speed: 15.8ms preprocess, 19.3ms inference, 14.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1794, 2008)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 18.9ms
# Speed: 8.8ms preprocess, 18.9ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1865, 1932)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 40.0ms
# Speed: 19.9ms preprocess, 40.0ms inference, 23.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1995, 1824)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 19.5ms
# Speed: 11.5ms preprocess, 19.5ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2127, 1704)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 18.9ms
# Speed: 10.7ms preprocess, 18.9ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2220, 1684)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 46.2ms
# Speed: 49.4ms preprocess, 46.2ms inference, 103.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2227, 1712)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 25.2ms
# Speed: 10.4ms preprocess, 25.2ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2095, 1724)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 24.7ms
# Speed: 9.9ms preprocess, 24.7ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1979, 1768)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 33.9ms
# Speed: 8.5ms preprocess, 33.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1930, 1813)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 18.8ms
# Speed: 7.6ms preprocess, 18.8ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1899, 1846)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 19.0ms
# Speed: 19.3ms preprocess, 19.0ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1901, 1889)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 26.3ms
# Speed: 25.5ms preprocess, 26.3ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1950, 1906)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 21.9ms
# Speed: 24.3ms preprocess, 21.9ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1987, 1890)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 21.4ms
# Speed: 12.1ms preprocess, 21.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (2015, 1885)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 24.9ms
# Speed: 10.4ms preprocess, 24.9ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1496, 1647)
#    ↳ Hand 1 wrist at (1965, 1919)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 15.4ms
# Speed: 8.2ms preprocess, 15.4ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1484, 1619)
#    ↳ Hand 1 wrist at (1925, 1888)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 16.0ms
# Speed: 19.5ms preprocess, 16.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1419, 1562)
#    ↳ Hand 1 wrist at (1922, 1789)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 15.3ms
# Speed: 8.2ms preprocess, 15.3ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1329, 1541)
#    ↳ Hand 1 wrist at (1940, 1728)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 25.2ms
# Speed: 17.0ms preprocess, 25.2ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1935, 1669)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 26.6ms
# Speed: 16.6ms preprocess, 26.6ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1909, 1681)
#
# 0: 640x640 5 persons, 1 truck, 1 parking meter, 19.0ms
# Speed: 15.5ms preprocess, 19.0ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1042, 1537)
#    ↳ Hand 1 wrist at (1880, 1699)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 1 handbag, 19.0ms
# Speed: 11.1ms preprocess, 19.0ms inference, 11.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1867, 1701)
#
# 0: 640x640 6 persons, 1 truck, 1 parking meter, 1 handbag, 19.0ms
# Speed: 9.4ms preprocess, 19.0ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1853, 1715)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 1 handbag, 19.3ms
# Speed: 31.5ms preprocess, 19.3ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1845, 1751)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 2 handbags, 19.0ms
# Speed: 11.1ms preprocess, 19.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1877, 1823)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 2 handbags, 37.7ms
# Speed: 9.5ms preprocess, 37.7ms inference, 12.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1864, 1872)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 2 handbags, 89.0ms
# Speed: 49.3ms preprocess, 89.0ms inference, 22.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1894, 2003)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 2 handbags, 23.9ms
# Speed: 14.1ms preprocess, 23.9ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1827, 2085)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 2 handbags, 19.4ms
# Speed: 29.1ms preprocess, 19.4ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1503, 1637)
#    ↳ Hand 1 wrist at (1876, 2197)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 2 handbags, 18.7ms
# Speed: 7.1ms preprocess, 18.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1502, 1659)
#    ↳ Hand 1 wrist at (1928, 2209)
#
# 0: 640x640 7 persons, 1 truck, 1 parking meter, 2 handbags, 18.4ms
# Speed: 8.5ms preprocess, 18.4ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1519, 1676)
#    ↳ Hand 1 wrist at (1954, 2268)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 2 handbags, 20.2ms
# Speed: 8.5ms preprocess, 20.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1609, 1712)
#    ↳ Hand 1 wrist at (2018, 2203)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 2 handbags, 27.1ms
# Speed: 20.6ms preprocess, 27.1ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1568, 1775)
#    ↳ Hand 1 wrist at (1941, 2105)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 2 handbags, 21.4ms
# Speed: 7.8ms preprocess, 21.4ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1563, 1765)
#    ↳ Hand 1 wrist at (1830, 1982)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 2 handbags, 18.7ms
# Speed: 11.3ms preprocess, 18.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1760, 1803)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 2 handbags, 18.9ms
# Speed: 10.0ms preprocess, 18.9ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1700, 1717)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 1 handbag, 18.5ms
# Speed: 7.2ms preprocess, 18.5ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1548, 1737)
#
# 0: 640x640 8 persons, 1 car, 1 parking meter, 18.6ms
# Speed: 8.6ms preprocess, 18.6ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1673, 1941)
#
# 0: 640x640 8 persons, 1 car, 1 parking meter, 38.0ms
# Speed: 13.5ms preprocess, 38.0ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1179, 1807)
#    ↳ Hand 1 wrist at (1677, 2083)
#
# 0: 640x640 8 persons, 1 car, 1 parking meter, 18.6ms
# Speed: 6.9ms preprocess, 18.6ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1319, 1873)
#    ↳ Hand 1 wrist at (1710, 2048)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 18.9ms
# Speed: 8.3ms preprocess, 18.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1442, 1885)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 18.7ms
# Speed: 8.3ms preprocess, 18.7ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1735, 1774)
#
# 0: 640x640 6 persons, 1 car, 1 parking meter, 20.6ms
# Speed: 6.6ms preprocess, 20.6ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 1 hand(s)
#    ↳ Hand 0 wrist at (1769, 1791)
#
# 0: 640x640 6 persons, 1 car, 1 parking meter, 18.5ms
# Speed: 8.1ms preprocess, 18.5ms inference, 14.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1316, 2430)
#    ↳ Hand 1 wrist at (1841, 1807)
#
# 0: 640x640 7 persons, 1 car, 1 parking meter, 18.7ms
# Speed: 7.0ms preprocess, 18.7ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1305, 2382)
#    ↳ Hand 1 wrist at (1892, 1758)
#
# 0: 640x640 5 persons, 1 car, 1 parking meter, 21.9ms
# Speed: 7.7ms preprocess, 21.9ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1287, 2402)
#    ↳ Hand 1 wrist at (1939, 1755)
#
# 0: 640x640 4 persons, 1 car, 1 parking meter, 18.9ms
# Speed: 7.2ms preprocess, 18.9ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1311, 2405)
#    ↳ Hand 1 wrist at (1972, 1763)
#
# 0: 640x640 4 persons, 1 car, 1 parking meter, 18.6ms
# Speed: 8.2ms preprocess, 18.6ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1314, 2423)
#    ↳ Hand 1 wrist at (1988, 1756)
#
# 0: 640x640 5 persons, 1 car, 1 parking meter, 19.5ms
# Speed: 12.9ms preprocess, 19.5ms inference, 14.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1296, 2419)
#    ↳ Hand 1 wrist at (1990, 1764)
#
# 0: 640x640 4 persons, 1 car, 1 parking meter, 18.5ms
# Speed: 15.2ms preprocess, 18.5ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1268, 2448)
#    ↳ Hand 1 wrist at (1982, 1749)
#
# 0: 640x640 3 persons, 1 car, 1 parking meter, 21.9ms
# Speed: 9.4ms preprocess, 21.9ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1240, 2466)
#    ↳ Hand 1 wrist at (1975, 1724)
#
# 0: 640x640 4 persons, 1 car, 1 parking meter, 19.0ms
# Speed: 7.3ms preprocess, 19.0ms inference, 13.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1246, 2484)
#    ↳ Hand 1 wrist at (1971, 1715)
#
# 0: 640x640 5 persons, 1 car, 1 parking meter, 18.5ms
# Speed: 7.4ms preprocess, 18.5ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1237, 2469)
#    ↳ Hand 1 wrist at (1961, 1724)
#
# 0: 640x640 5 persons, 1 car, 1 parking meter, 18.6ms
# Speed: 12.1ms preprocess, 18.6ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1243, 2453)
#    ↳ Hand 1 wrist at (1958, 1733)
#
# 0: 640x640 5 persons, 1 car, 1 parking meter, 18.5ms
# Speed: 8.0ms preprocess, 18.5ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1233, 2455)
#    ↳ Hand 1 wrist at (1965, 1744)
#
# 0: 640x640 5 persons, 1 car, 1 parking meter, 18.8ms
# Speed: 9.7ms preprocess, 18.8ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1211, 2445)
#    ↳ Hand 1 wrist at (1966, 1751)
#
# 0: 640x640 5 persons, 1 car, 1 parking meter, 18.6ms
# Speed: 6.9ms preprocess, 18.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1138, 2416)
#    ↳ Hand 1 wrist at (1962, 1752)
#
# 0: 640x640 5 persons, 1 car, 1 parking meter, 19.4ms
# Speed: 9.4ms preprocess, 19.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1077, 2343)
#    ↳ Hand 1 wrist at (1952, 1747)
# ✅ Hand entered disinfection zone at (1077, 2343)
# 🎯 Closest person to hand: ID 3 (distance=528.35)
#
# 0: 640x640 5 persons, 1 parking meter, 19.0ms
# Speed: 8.0ms preprocess, 19.0ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1082, 2311)
#    ↳ Hand 1 wrist at (1933, 1746)
# ✅ Hand entered disinfection zone at (1082, 2311)
# 🎯 Closest person to hand: ID 3 (distance=622.80)
#
# 0: 640x640 4 persons, 1 toilet, 18.7ms
# Speed: 7.4ms preprocess, 18.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1115, 2314)
#    ↳ Hand 1 wrist at (1934, 1730)
#
# 0: 640x640 3 persons, 1 parking meter, 140.9ms
# Speed: 114.7ms preprocess, 140.9ms inference, 16.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1133, 2293)
#    ↳ Hand 1 wrist at (1925, 1727)
#
# 0: 640x640 3 persons, 1 parking meter, 24.2ms
# Speed: 9.4ms preprocess, 24.2ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1133, 2279)
#    ↳ Hand 1 wrist at (1924, 1724)
#
# 0: 640x640 3 persons, 24.1ms
# Speed: 8.6ms preprocess, 24.1ms inference, 14.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1109, 2252)
#    ↳ Hand 1 wrist at (1917, 1727)
#
# 0: 640x640 3 persons, 18.6ms
# Speed: 11.0ms preprocess, 18.6ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1057, 2221)
#    ↳ Hand 1 wrist at (1892, 1737)
# ✅ Hand entered disinfection zone at (1057, 2221)
# 🎯 Closest person to hand: ID 3 (distance=629.36)
#
# 0: 640x640 4 persons, 133.9ms
# Speed: 147.0ms preprocess, 133.9ms inference, 87.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖐️ Detected 2 hand(s)
#    ↳ Hand 0 wrist at (1017, 2182)
#    ↳ Hand 1 wrist at (1885, 1750)
# ✅ Hand entered disinfection zone at (1017, 2182)
# 🎯 Closest person to hand: ID 3 (distance=425.99)
# 處理完成
